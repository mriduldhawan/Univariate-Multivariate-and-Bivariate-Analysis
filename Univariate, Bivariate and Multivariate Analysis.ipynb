# %% [markdown]
# # Univariate, Bivariate and Multivariate Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('iris.csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  target
# 0           5.1          3.5           1.4          0.2       0
# 1           4.9          3.0           1.4          0.2       0
# 2           4.7          3.2           1.3          0.2       0
# 3           4.6          3.1           1.5          0.2       0
# 4           5.0          3.6           1.4          0.2       0

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Univariate Analysis

# %%
df_setosa = df.loc[df['target']==0]
df_virginica = df.loc[df['target']==1]
df_versicolor = df.loc[df['target']==2]

# %%
plt.plot(df_setosa['sepal_length'], np.zeros_like(df_setosa['sepal_length']),'o')
plt.plot(df_virginica['sepal_length'], np.zeros_like(df_virginica['sepal_length']))
plt.plot(df_versicolor['sepal_length'], np.zeros_like(df_versicolor['sepal_length']),'o')
plt.xlabel('Sepal length')
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
sns.FacetGrid(df,hue='target',size=5).map(plt.scatter,'petal_length','petal_width').add_legend();
plt.show()
# Out:
# C:\Users\TEMP.DESKTOP-M8QKDFI\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Multivariate Analysis

# %%
sns.pairplot(df,hue='target',size=2)
# Out:
# C:\Users\TEMP.DESKTOP-M8QKDFI\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
